# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv('temperatures.csv')

# %%
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
df.tail()
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 112  30.27  27.83  25.37   29.81    25.58    32.58    31.33    27.83
# 113  30.29  28.05  25.08   29.72    24.90    31.82    32.00    27.81
# 114  31.04  28.10  25.67   29.90    25.74    31.68    31.87    28.27
# 115  31.98  30.11  28.01   31.63    28.33    34.57    32.28    30.03
# 116  32.29  29.60  27.18   31.42    27.95    34.13    32.41    29.69

# %%
df.isnull().sum()
# Out:
# YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# MDK

# %%
x = df[['YEAR']]
y = df[['JAN']]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
xtrain.shape
ytrain.shape
# Out:
# (81, 1)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print(f"intercept: {model.intercept_}")
# Out:
# intercept: [-5.523996]

# %%
print(f"slope: {model.coef_}")
# Out:
# slope: [[0.01490451]]

# %%
prediction=model.predict(xtest)

# %%
from sklearn import metrics
print("Mean Absolute Error:", metrics.mean_absolute_error(xtest, prediction))
print("Mean Squared Error ", metrics.mean_squared_error(xtest, prediction))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(xtest, prediction)))
# Out:
# Mean Absolute Error: 1924.1069167936532
# Mean Squared Error  3703266.4877100345
# Root Mean Squared Error: 1924.3873018989796

# %%
import matplotlib.pyplot as mpl
mpl.scatter(x, y, color = 'g')
mpl.plot(x, model.predict(x), color= 'k')
mpl.show()

# %%
x = df[['YEAR']]
y = df[['MAR']]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
xtrain.shape
ytrain.shape
# Out:
# (81, 1)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print(f"intercept: {model.intercept_}")
# Out:
# intercept: [-5.21275612]

# %%
print(f"slope: {model.coef_}")
# Out:
# slope: [[0.01750969]]

# %%
prediction1=model.predict(xtest)

# %%
from sklearn import metrics
print("Mean Absolute Error:", metrics.mean_absolute_error(xtest, prediction1))
print("Mean Squared Error ", metrics.mean_squared_error(xtest, prediction1))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(xtest, prediction1)))
# Out:
# Mean Absolute Error: 1935.7516297486427
# Mean Squared Error  3748014.1747569176
# Root Mean Squared Error: 1935.9788673322128

# %%
import matplotlib.pyplot as mpl
mpl.scatter(x, y, color = 'g')
mpl.plot(x, model.predict(x), color= 'k')
mpl.show()

# %%
x = df[['YEAR']]
y = df[['APR']]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
xtrain.shape
ytrain.shape
# Out:
# (81, 1)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print(f"intercept: {model.intercept_}")
# Out:
# intercept: [3.80712332]

# %%
print(f"slope: {model.coef_}")
# Out:
# slope: [[0.01445102]]

# %%
prediction2=model.predict(xtest)

# %%
from sklearn import metrics
print("Mean Absolute Error:", metrics.mean_absolute_error(xtest, prediction2))
print("Mean Squared Error ", metrics.mean_squared_error(xtest, prediction2))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(xtest, prediction2)))
# Out:
# Mean Absolute Error: 1930.0863580091286
# Mean Squared Error  3725929.904497959
# Root Mean Squared Error: 1930.266796196308

# %%
import matplotlib.pyplot as mpl
mpl.scatter(x, y, color = 'g')
mpl.plot(x, model.predict(x), color= 'k')
mpl.show()

# %%
x = df[['YEAR']]
y = df[['JUN']]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
xtrain.shape
ytrain.shape
# Out:
# (81, 1)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print(f"intercept: {model.intercept_}")
# Out:
# intercept: [20.82639083]

# %%
print(f"slope: {model.coef_}")
# Out:
# slope: [[0.0060833]]

# %%
prediction3=model.predict(xtest)

# %%
from sklearn import metrics
print("Mean Absolute Error:", metrics.mean_absolute_error(xtest, prediction3))
print("Mean Squared Error ", metrics.mean_squared_error(xtest, prediction3))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(xtest, prediction3)))
# Out:
# Mean Absolute Error: 1922.8053251919478
# Mean Squared Error  3698256.7947185156
# Root Mean Squared Error: 1923.0852281473424

# %%
import matplotlib.pyplot as mpl
mpl.scatter(x, y, color = 'g')
mpl.plot(x, model.predict(x), color= 'k')
mpl.show()

# %%
x = df[['YEAR']]
y = df[['MAY']]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
xtrain.shape
ytrain.shape
# Out:
# (81, 1)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print(f"intercept: {model.intercept_}")
# Out:
# intercept: [13.15966701]

# %%
print(f"slope: {model.coef_}")
# Out:
# slope: [[0.01042711]]

# %%
prediction4=model.predict(xtest)

# %%
from sklearn import metrics
print("Mean Absolute Error:", metrics.mean_absolute_error(xtest, prediction4))
print("Mean Squared Error ", metrics.mean_squared_error(xtest, prediction4))
print("Root Mean Squared Error:", np.sqrt(metrics.mean_squared_error(xtest, prediction4)))
# Out:
# Mean Absolute Error: 1926.4581759513499
# Mean Squared Error  3712142.39563499
# Root Mean Squared Error: 1926.692086358116

# %%
import matplotlib.pyplot as mpl
mpl.scatter(x, y, color = 'g')
mpl.plot(x, model.predict(x), color= 'k')
mpl.show()
